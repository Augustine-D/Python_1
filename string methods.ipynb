# %%
a = ' hello world!!! '
b =  'I love football...'
c = 'Berlin,Tokyo,Jaipor,Washinton D.C,London'

# %%
a
# Out:
# ' hello world!!! '

# %%
b
# Out:
# 'I love football...'

# %%
c
# Out:
# 'Berlin,Tokyo,Jaipor,Washinton D.C,London'

# %% [markdown]
# # strip method

# %%
a.strip()
# Out:
# 'hello world!!!'

# %% [markdown]
# # lower

# %%
b.lower()
# Out:
# 'i love football...'

# %%
b.lower()
# Out:
# 'i love football...'

# %% [markdown]
# # uper

# %%
a.upper()
# Out:
# ' HELLO WORLD!!! '

# %%
b.upper()
# Out:
# 'I LOVE FOOTBALL...'

# %%
c.upper()
# Out:
# 'BERLIN,TOKYO,JAIPOR,WASHINTON D.C,LONDON'

# %% [markdown]
# # Replace

# %%
a.replace('hello', 'hi')
# Out:
# ' hi world!!! '

# %%
 a = a.replace('hello', 'hi')

# %%
a
# Out:
# ' hi world!!! '

# %%
b.replace('love','hate')
# Out:
# 'I hate football...'

# %%
b.replace('a','e')
# Out:
# 'I love footbell...'

# %%
c.replace(' ','+')
# Out:
# 'Berlin,Tokyo,Jaipor,Washinton+D.C,London'

# %% [markdown]
# # split

# %%
a
# Out:
# ' hi world!!! '

# %%
a.split(' ')
# Out:
# ['', 'hi', 'world!!!', '']

# %%
a.split()
# Out:
# ['hi', 'world!!!']

# %%
b.split(
)
# Out:
# ['I', 'love', 'football...']

# %%
c.split(',')
# Out:
# ['Berlin', 'Tokyo', 'Jaipor', 'Washinton D.C', 'London']

# %% [markdown]
# # in

# %%
'a' in a
# Out:
# False

# %%
'b' in c
# Out:
# False

# %%
'B' in c
# Out:
# True

# %%
c = c.lower()

# %%
'b' in c
# Out:
# True

# %%
'B' not in c
# Out:
# True

# %%
'b' not in c
# Out:
# False

# %% [markdown]
# # backslash

# %%
x = ' he is a \'legend\' in cricket'

# %% [markdown]
# # \t

# %%
x = 'hello\tworld'

# %%
print (x)
# Out:
# hello world

# %%
x = 'hello\nworld'

# %%
print(x)
# Out:
# hello
# world
