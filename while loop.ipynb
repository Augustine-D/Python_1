# %%
i=0
while(i<4
     ):
    print ('hello')
    i=i+1
# Out:
# hello
# hello
# hello
# hello

# %%
i=0
while(i<5):
    print(i)
    i=i+2
# Out:
# 0
# 2
# 4

# %%
i=0
j=0
while (i+j<10):
    print(i,j)
    i=i+1
    j= j+2
# Out:
# 0 0
# 1 2
# 2 4
# 3 6
