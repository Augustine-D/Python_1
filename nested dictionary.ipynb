# %%
student = {'jon':{'history':10,'physics':98,'chemistry':65,'Geog':88,'Maths':50},
          'martina':{'history':95,'physics':58,'chemistry':35,'Geog':90,'Maths':70},
          'kartic':{'history':60,'physics':67,'chemistry':65,'Geog':68,'Maths':90}
          }

# %%
student
# Out:
# {'jon': {'history': 10,
#   'physics': 98,
#   'chemistry': 65,
#   'Geog': 88,
#   'Maths': 50},
#  'martina': {'history': 95,
#   'physics': 58,
#   'chemistry': 35,
#   'Geog': 90,
#   'Maths': 70},
#  'kartic': {'history': 60,
#   'physics': 67,
#   'chemistry': 65,
#   'Geog': 68,
#   'Maths': 90}}

# %%
set(student)
# Out:
# {'jon', 'kartic', 'martina'}

# %%
student['jon']['history']
# Out:
# 10

# %%
student['martina']['physics']
# Out:
# 58

# %%
for i in student:
    print('I got', student[i]['history'], 'marks')
# Out:
# I got 10 marks
# I got 95 marks
# I got 60 marks

# %%
for i in student:
    for j in student[i]:
        print(j)
# Out:
# history
# physics
# chemistry
# Geog
# Maths
# history
# physics
# chemistry
# Geog
# Maths
# history
# physics
# chemistry
# Geog
# Maths

# %%
subjects = []

for j in student['martina']:
        subjects.append(j)

# %%
subjects
# Out:
# ['history', 'physics', 'chemistry', 'Geog', 'Maths']

# %%
marks = []
for i in subjects:
    for j in student:
        marks.append(student[j][i])
    print(i,j, max(marks))
# Out:
# history kartic 95
# physics kartic 98
# chemistry kartic 98
# Geog kartic 98
# Maths kartic 98
