# %%
a = 'hello'

# %%
b = "hello"

# %%
c = '''hello'''

# %%
print (a,b,c)
# Out:
# hello hello hello

# %%
e ='hello this is my first string program'

# %% [markdown]
# # string indexing

# %%
a = 'hello world!!!'

# %%
a[0]
# Out:
# 'h'

# %%
a[-1]
# Out:
# '!'

# %%
a[::-1]
# Out:
# '!!!dlrow olleh'

# %%
b = input ('Name: ')
b[::-1]
# Out:
# Name: AUGUSTINE
# 'ENITSUGUA'

# %% [markdown]
# # string slicing

# %%
a
# Out:
# 'hello world!!!'

# %%
a[1:]
# Out:
# 'ello world!!!'

# %%
a[0:2:2]
# Out:
# 'h'

# %%
e = 'hello this is my first string program'

# %%
e[:-1]
# Out:
# 'hello this is my first string progra'

# %%
e[:5]
# Out:
# 'hello'

# %%
e[:6]
# Out:
# 'hello '

# %%
e[:4]
# Out:
# 'hell'

# %% [markdown]
# # skipping element

# %%
e[0:10:1]
# Out:
# 'hello this'

# %%
e[0:10:2]
# Out:
# 'hloti'

# %%
e[0:10:3]
# Out:
# 'hlts'
