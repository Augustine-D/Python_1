# %%
# !pip install numpy

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5,6])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
li=[1,2,3,4,5,6,67,7,8]

# %%
arr2=numpy.array(li)

# %%
arr2
# Out:
# array([ 1,  2,  3,  4,  5,  6, 67,  7,  8])

# %%
set(arr2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 67}
