# %% [markdown]
# # User input

# %%
input()
# Out:
# 10
# '10'

# %%
input("Enter your Age:")
# Out:
# Enter your Age:12
# '12'

# %%
x = input ("Name: ")
# Out:
# Name: AUGUSTINE

# %%
x
# Out:
# 'AUGUSTINE'

# %%
y = input("Enter your Age:")
# Out:
# Enter your Age:10

# %%
type (y)
# Out:
# str

# %%
y = float (input("Enter your Age:"))
# Out:
# Enter your Age:10

# %%
type(y)
# Out:
# float

# %%
print ("your name is " + x)
# Out:
# your name is AUGUSTINE

# %%
print ("your name is " ,x)
# Out:
# your name is  AUGUSTINE

# %%
s = input ('Your name please')

x = input ('Your age please')

y = input ('Fathers age please')

print (s+ " is " + x +" years old and his fathers age is "+ y + " years old")
# Out:
# Your name pleaseK
# Your age please2
# Fathers age please4
# K is Ks 2 years old and his fathers age is 4 years old

# %%
x = int (input("Sam:: Enter your age: "))
# Out:
# Sam:: Enter your age: 25

# %%
y = x+30

# %%
print("Sam is ", x, "years old and his father is", y, " years old.")
# Out:
# Sam is  25 years old and his father is 55  years old.

# %%
print("Sam is {a}years old and his father is {b} years old." .format(a=x,b=y))
# Out:
# Sam is 25years old and his father is 55 years old.

# %%
print("Sam is {0} years old and his father is {1} years old." .format(x,y))
# Out:
# Sam is 25 years old and his father is 55 years old.

# %%
print("Sam is {} years old and his father is {} years old." .format(x,y))
# Out:
# Sam is 25 years old and his father is 55 years old.
