# %% [markdown]
# # List

# %%
# list are mutable meaning they can be modified
# they are defined in square brackets
# list are ordered meaning it is indexed

# %%
li = [1,2,3,4,5]

# %%
li
# Out:
# [1, 2, 3, 4, 5]

# %%
l2 = ['yaw', 'ama', 1,3]

# %%
l3 = [10, 20, 30, 40, 50]

# %%
l3 [2]
# Out:
# 30

# %%
l3 [0]
# Out:
# 10

# %%
l3 [-1]
# Out:
# 50

# %%
len(l3)
# Out:
# 5

# %%
l3[len(l3)-1]
# Out:
# 50

# %%
l3[0:3]
# Out:
# [10, 20, 30]

# %%
l3[1:6]
# Out:
# [20, 30, 40, 50]

# %%
l3[1:]
# Out:
# [20, 30, 40, 50]

# %%
l3[3:]
# Out:
# [40, 50]

# %%
list = ['sam','john', 'sarah','kartik','jason','matt']

# %%
list [0:6:1]
# Out:
# ['sam', 'john', 'sarah', 'kartik', 'jason', 'matt']

# %%
list [0:6:2]
# Out:
# ['sam', 'sarah', 'jason']

# %%
list [3:6:2]
# Out:
# ['kartik', 'matt']

# %%
list[::3]
# Out:
# ['sam', 'kartik']

# %%
list [::2]
# Out:
# ['sam', 'sarah', 'jason']

# %%
list [::-1]
#printing reverse of a list
# Out:
# ['matt', 'jason', 'kartik', 'sarah', 'john', 'sam']
