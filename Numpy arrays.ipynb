# %% [markdown]
# # Numpy arrays

# %%
import numpy as np
list1 = [1,2,3,'a',True]

# %%
list1
# Out:
# [1, 2, 3, 'a', True]

# %%
arr1=np.array(list1)

# %%
arr1
# Out:
# array(['1', '2', '3', 'a', 'True'], dtype='<U11')

# %%
arr2 = np.array([1,2,3,4,5,5.6])

# %%
arr2
# Out:
# array([1. , 2. , 3. , 4. , 5. , 5.6])

# %%
arr3= np.array([1,2,3,True])

# %%
arr3
# Out:
# array([1, 2, 3, 1])

# %%
arr4= np.array([1,2,3,False])

# %%
arr4
# Out:
# array([1, 2, 3, 0])
