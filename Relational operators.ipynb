# %% [markdown]
#  # Relational operators

# %%
# there are 6 relational operators
# <, <=, >, >=, ==, !=

# %%
10 > 7
# Out:
# True

# %%
10 < 7
# Out:
# False

# %%
#less than

# %%
5< 7
# Out:
# True

# %%
x = 10
y=12

# %%
x < y
# Out:
# True

# %%
x> y
# Out:
# False

# %%
#less than ewual to

# %%
11<=12
# Out:
# True

# %%
13<=12
# Out:
# False

# %%
x = 12
y = 12

# %%
x <= y
# Out:
# True

# %%
y > x
# Out:
# False

# %%
x!= y
# Out:
# False

# %%
y != x
# Out:
# False

# %%
y == x
# Out:
# True

# %%
x == y
# Out:
# True
