# %%
var = 10

# %%
var = 20

# %%
var_1 = 10

# %%
Var = 20

# %%
_var = 10

# %%
_Var = 20

# %%
_var
# Out:
# 10

# %% [markdown]
# # Arithmetic operations

# %%
x = 2
y = 3

# %%
#addition
x + y
# Out:
# 5

# %%
x - y
# Out:
# -1

# %%
x*y
# Out:
# 6

# %% [markdown]
# # Division

# %%
x/y
# Out:
# 0.6666666666666666

# %%
x**y
# Out:
# 8

# %%
pow(x,y)
# Out:
# 8

# %%
#quotiant
x//y
# Out:
# 0

# %%
#modulus
x % y
# Out:
# 2
