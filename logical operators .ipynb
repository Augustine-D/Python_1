# %%
# logical operators
# & logical AND
# | logical OR

#BOOLEAN VALES
#TRUE = 1
#FALSE = 0

# %%
10
# Out:
# 10

# %%
bool(10)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool (0)
# Out:
# False

# %%
# TRUE & TRUE = TRUE
# TRUE & FALSE = FALSE
# FALSE & FALSE = FALSE
# TRUE & FALSE = FALSE
#
# 
# TRUE | TRUE = TRUE
# TRUE | FALSE = TRUE
# FALSE | FALSE = FALSE
# TRUE | FALSE = TRUE


# TRUE + FALSE = 1
# FALSE + FALSE = 0
# TRUE * FALSE = 0

# %%
True * True
# Out:
# 1

# %%
False * True
# Out:
# 0

# %%
False * False
# Out:
# 0

# %%
True + False
# Out:
# 1

# %%
True & True
# Out:
# True

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True | True
# Out:
# True

# %%
True | False
# Out:
# True

# %%
False | False
# Out:
# False

# %%
x = 10

# %%
x< 7
# Out:
# False

# %%
x > 5
# Out:
# True

# %%
(x > 5) & (x < 9)
# Out:
# False

# %%
(x > 5) | (x < 9)
# Out:
# True
